# %%
import pandas as pd
from ast import literal_eval

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)

# %%
file = '2000k-2100k.csv'

# %%
df = pd.read_csv(f'../data/preprocessed/{file}', converters={'tokens': literal_eval, 'nltk_pos': literal_eval, 'spacy_pos': literal_eval,'spacy_label': literal_eval,})
df.head()
# Out:
#   patent_number        date                                  title  \
# 0    US2000000A  1932-05-12     Vehicle wheel construction \n
# 1    US2000001A  1932-09-20                        Bearing \n
# 2    US2000002A  1931-06-22  Control valve for gas burners \n
# 3    US2000003A  1932-12-10        Preparation of pigments \n
# 4    US2000004A  1931-08-26               Insect repellent \n
#
#                               spacy_pos spacy_label  is_prpn_spacy  \
# 0            [PROPN, NOUN, NOUN, SPACE]          []              1
# 1                         [VERB, SPACE]          []              0
# 2  [NOUN, VERB, ADP, NOUN, NOUN, SPACE]          []              0
# 3              [NOUN, ADP, NOUN, SPACE]          []              0
# 4                   [PROPN, ADJ, SPACE]          []              1
#
#    is_person_spacy
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
df['is_person_spacy'] = df['spacy_label'].apply(lambda x: 1 if 'PERSON' in x else 0)

# %%
df['spacy_pos_len'] = df['spacy_pos'].apply(len)

# %%
len(df)
# Out:
# 99869

# %%
df_inventor = df[(df['is_person_spacy'] == 1)&(df['spacy_pos_len'] <= 2)]

# %%
a = []

if len(a) > 0:
    print(a[-1])

# %%
a = 'Thermometer \n'
a
# Out:
# 'Thermometer \n'

# %%
df_inventor['spacy_pos_len'].value_counts()
# Out:
# 2    412
# 1     22
# Name: spacy_pos_len, dtype: int64

# %%
df_inventor[['title', 'spacy_pos', 'spacy_label']].head(100)
# Out:
#                         title       spacy_pos spacy_label
# 92        Thermometer \n       [PROPN, SPACE]    [PERSON]
# 210            Carton \n       [PROPN, SPACE]    [PERSON]
# 311             Jetty \n       [PROPN, SPACE]    [PERSON]
# 312             Jetty \n       [PROPN, SPACE]    [PERSON]
# 406        Vulcanizer \n       [PROPN, SPACE]    [PERSON]
# 544            Barrel \n       [PROPN, SPACE]    [PERSON]
# 731             Meter \n       [PROPN, SPACE]    [PERSON]
# 852            Shears \n        [NOUN, SPACE]    [PERSON]
# 1254           Harrow \n       [PROPN, SPACE]    [PERSON]
# 1849           Carton \n       [PROPN, SPACE]    [PERSON]
# 1858           Barrel \n       [PROPN, SPACE]    [PERSON]
# 1983           Carton \n       [PROPN, SPACE]    [PERSON]
# 2254           Harrow \n       [PROPN, SPACE]    [PERSON]
# 2484           Carton \n       [PROPN, SPACE]    [PERSON]
# 2562        Bulldozer \n       [PROPN, SPACE]    [PERSON]
# 2869           Meter bellows     [NOUN, VERB]    [PERSON]
# 2873        Altimeter \n       [PROPN, SPACE]    [PERSON]
# 3893         Keyboard \n       [PROPN, SPACE]    [PERSON]
# 3918            Meter \n       [PROPN, SPACE]    [PERSON]
# 4993         Amidines \n        [NOUN, SPACE]    [PERSON]
# 5110        Amplifier \n       [PROPN, SPACE]    [PERSON]
# 5345               macdonald          [PROPN]    [PERSON]
# 5360              Cap \n       [PROPN, SPACE]    [PERSON]
# 5371            Shelf \n       [PROPN, SPACE]    [PERSON]
# 5469         Windmill \n       [PROPN, SPACE]    [PERSON]
# 5538             Yarn \n       [PROPN, SPACE]    [PERSON]
# 6021         Windmill \n       [PROPN, SPACE]    [PERSON]
# 6049        Amplifier \n       [PROPN, SPACE]    [PERSON]
# 6472           Carton \n       [PROPN, SPACE]    [PERSON]
# 6571         Scaffold \n        [NOUN, SPACE]    [PERSON]
# 6729            Kazoo \n       [PROPN, SPACE]    [PERSON]
# 7482            Truss \n       [PROPN, SPACE]    [PERSON]
# 7584                williams          [PROPN]    [PERSON]
# 7930     Synchroscope \n       [PROPN, SPACE]    [PERSON]
# 8382             Jack \n       [PROPN, SPACE]    [PERSON]
# 8449   Dispensing receptacle     [VERB, NOUN]    [PERSON]
# 8944           Carton \n       [PROPN, SPACE]    [PERSON]
# 9497           Shears \n        [NOUN, SPACE]    [PERSON]
# 9523           Goggle \n       [PROPN, SPACE]    [PERSON]
# 9921             Slip \n       [PROPN, SPACE]    [PERSON]
# 10126       Amplifier \n       [PROPN, SPACE]    [PERSON]
# 10170        Silencer \n       [PROPN, SPACE]    [PERSON]
# 10194         Caisson \n       [PROPN, SPACE]    [PERSON]
# 10211               brussell          [PROPN]    [PERSON]
# 10248       Amplifier \n       [PROPN, SPACE]    [PERSON]
# 10570          Shears \n        [NOUN, SPACE]    [PERSON]
# 10984           Shelf \n       [PROPN, SPACE]    [PERSON]
# 11927            Jack \n       [PROPN, SPACE]    [PERSON]
# 11969         Cleaner \n       [PROPN, SPACE]    [PERSON]
# 12105                zlawick           [VERB]    [PERSON]
# 12106     Thermometer \n       [PROPN, SPACE]    [PERSON]
# 12125          Carton \n       [PROPN, SPACE]    [PERSON]
# 12322            Slip \n       [PROPN, SPACE]    [PERSON]
# 12324        Silencer \n       [PROPN, SPACE]    [PERSON]
# 12330            Slip \n       [PROPN, SPACE]    [PERSON]
# 12538        Bookrack \n       [PROPN, SPACE]    [PERSON]
# 13220          Carton \n       [PROPN, SPACE]    [PERSON]
# 13317            Coat \n       [PROPN, SPACE]    [PERSON]
# 13867          Carton \n       [PROPN, SPACE]    [PERSON]
# 15110           Label \n       [PROPN, SPACE]    [PERSON]
# 15271          Carton \n       [PROPN, SPACE]    [PERSON]
# 15770        Windmill \n       [PROPN, SPACE]    [PERSON]
# 16081           Screw \n        [NOUN, SPACE]    [PERSON]
# 16527         Cigagette case    [PROPN, NOUN]    [PERSON]
# 16645                  Chuck          [PROPN]    [PERSON]
# 17045                 Beacon          [PROPN]    [PERSON]
# 17105       Amplifier \n       [PROPN, SPACE]    [PERSON]
# 17516       Amplifier \n       [PROPN, SPACE]    [PERSON]
# 17543           Screw \n        [NOUN, SPACE]    [PERSON]
# 17643          Carton \n       [PROPN, SPACE]    [PERSON]
# 17979          Tucker \n       [PROPN, SPACE]    [PERSON]
# 18077        Silencer \n       [PROPN, SPACE]    [PERSON]
# 18265        Analyzer \n       [PROPN, SPACE]    [PERSON]
# 18881        Windmill \n       [PROPN, SPACE]    [PERSON]
# 19214     Thermometer \n       [PROPN, SPACE]    [PERSON]
# 19361          Harrow \n       [PROPN, SPACE]    [PERSON]
# 20653          Carton \n       [PROPN, SPACE]    [PERSON]
# 20659      Vulcanizer \n       [PROPN, SPACE]    [PERSON]
# 21273     Thermometer \n       [PROPN, SPACE]    [PERSON]
# 21628       Amplifier \n       [PROPN, SPACE]    [PERSON]
# 21687     Thermometer \n       [PROPN, SPACE]    [PERSON]
# 21694           Screw \n        [NOUN, SPACE]    [PERSON]
# 21956       Liquefier \n       [PROPN, SPACE]    [PERSON]
# 22297      Vulcanizer \n       [PROPN, SPACE]    [PERSON]
# 22463           Truss \n       [PROPN, SPACE]    [PERSON]
# 22485       Amplifier \n       [PROPN, SPACE]    [PERSON]
# 22658            Jack \n       [PROPN, SPACE]    [PERSON]
# 22888        Silencer \n       [PROPN, SPACE]    [PERSON]
# 23651            Slip \n       [PROPN, SPACE]    [PERSON]
# 23813       Altimeter \n       [PROPN, SPACE]    [PERSON]
# 24301       Altimeter \n       [PROPN, SPACE]    [PERSON]
# 24302       Altimeter \n       [PROPN, SPACE]    [PERSON]
# 24649             Rjszdorfer          [PROPN]    [PERSON]
# 24742       Bulldozer \n       [PROPN, SPACE]    [PERSON]
# 24769        Windmill \n       [PROPN, SPACE]    [PERSON]
# 24782           Crochet hook    [PROPN, NOUN]    [PERSON]
# 24799      Vulcanizer \n       [PROPN, SPACE]    [PERSON]
# 26307       Amplifier \n       [PROPN, SPACE]    [PERSON]
# 26422          Goggle \n       [PROPN, SPACE]    [PERSON]
# 26782        Silencer \n       [PROPN, SPACE]    [PERSON]

# %%
df_non_inventor[['title']].head(100)
# Out:
#                                                                                                                           title
# 0                                                                                            Vehicle wheel construction \n
# 1                                                                                                               Bearing \n
# 2                                                                                         Control valve for gas burners \n
# 3                                                                                               Preparation of pigments \n
# 4                                                                                                      Insect repellent \n
# 5                                                                                   Continuous absorption refrigeration \n
# 6                                                                                                  Paper making machine \n
# 7                                                                                    Torch cutting or welding apparatus \n
# 8                                                                                                             Dispenser \n
# 9                                                                               Feed water heater for locomotives, etc. \n
# 10                                                                                                   Oscillation system \n
# 11                                                                                                  Brake shoe expander \n
# 12                                                                                        Combination wrench and pliers \n
# 13                                                             Method of producing artificial straw and product thereof \n
# 14                                                                                                         Telautograph \n
# 15                                                                      Safety arrow release device for bows in archery \n
# 16                                                                                                 Multiple fuse device \n
# 17                                                                                        Electrical cleaning of fluids \n
# 18                                                          Method for the separation of emulsions by electrical action \n
# 19                                                                                      Art of electrical precipitation \n
# 20                                                 Method of electrical precipitation of suspended particles from gases \n
# 21                                                                                                    Ice cream freezer \n
# 22                                                                                                    Ice cream freezer \n
# 23                                                                                  Ice cream freezer for refrigerators \n
# 24                                                                                                             Vibrator \n
# 25                                                                                                             Vibrator \n
# 26                                                                                                             Vibrator \n
# 27                                                                                                      Molding machine \n
# 28                                                                                          Compounding of rubber, etc. \n
# 29                                                                                      Keyboard perforator and counter \n
# 30                                                                         Covering for surfaces exposed to the weather \n
# 31                                                                                          Composition of matter, etc. \n
# 32                                                                                                    Transmission line \n
# 33                                                                       Process for the manufacture of thioindigo dyes \n
# 34   Process for the manufacture of certain para-n-sec-alkylamino-phenols and other substituted phenols and their salts \n
# 35                                                                                                 Type retaining plate \n
# 36                                                                                                Tire mounting machine \n
# 37                                       Apparatus for automatically determining the exposure in photographic apparatus \n
# 38                                                                    Apparatus for the production of ammonium sulphate \n
# 39                                                                   Rubber composition and method of preserving rubber \n
# 40                                                                   Rubber composition and method of preserving rubber \n
# 41                                                                   Rubber composition and method of preserving rubber \n
# 42                                                                                              Compressed foam gelatin \n
# 43                                           Process for azeotropic drying of mixtures of water and alcohols or ketones \n
# 44                                                                                                          Antioxidant \n
# 45                                                                                                          Antioxidant \n
# 46                                                                                                 Water level recorder \n
# 47                                                                                    Process of making artificial silk \n
# 48                                                                                    Process of making artificial silk \n
# 49                                                                                   Automatic variable pitch propeller \n
# 50                                                                                                              Pigment \n
# 51                                        Metal compound containing an isoindole nucleus and process of making the same \n
# 52                                             Process for the manufacture of colored compounds and the product thereof \n
# 53                                                                        Process for the production of carboxylic acid \n
# 54                                                                                                Stevedoring apparatus \n
# 55                                                                                                      Flare container \n
# 56                                                                   Method and apparatus for compressing and indenting \n
# 57                                                                           Automatic gauge control and means therefor \n
# 58                                                                                              Three-color photography \n
# 59                                                                                                Folder paper fastener \n
# 60                                                                                                     Ornamental cross \n
# 61                                                                                      Manufacture of diaryl sulphones \n
# 62                                                                                               Fabric folding machine \n
# 63                                                                                                      Folding machine \n
# 64                                                                                                           Respirator \n
# 65                                                                                           Fiber tube rolling machine \n
# 66                                                                                   Artificial limb joint construction \n
# 67                                                                                                Collapsible container \n
# 68                                                                                                 Aeronautical machine \n
# 69                                                                                           Preparation of lead alkyls \n
# 70                                                                                         Card roller mounting machine \n
# 71                                                                                      Card clothing resetting machine \n
# 72                                                                                                         Road machine \n
# 73                                                                               Body garment and method of manufacture \n
# 74                                                                                           Supervised electric system \n
# 75                                                                                                          Clam-opener \n
# 76                                                                                                           Roller bit \n
# 77                                              Apparatus for and method of applying surfacing material to a fabric web \n
# 78                                                                                                           Hand brake \n
# 79                                                                                                              Machine \n
# 80                                                                                                               Switch \n
# 81                                                                                                    Loose leaf binder \n
# 82                                                                       Artificial manure and method of producing same \n
# 83                                                                    Facsimile printing telegraph system and apparatus \n
# 84                                                                                      Short wave receiver arrangement \n
# 85                                                                                                 Pulp molding machine \n
# 86                                                                                                       Shock absorber \n
# 87                                                                                                               Siphon \n
# 88                                                                                                     Type bar machine \n
# 89                                                                                                 Hand brake mechanism \n
# 90                                                                                            Camera focusing mechanism \n
# 91                                                             Pressure delivery of fuel in internal combustion engines \n
# 93                                                                                  Neckband and collar finishing press \n
# 94                                                                                                      Art of printing \n
# 95                                                                                         Insulated electric conductor \n
# 96                                                                               Process for manufacturing formaldehyde \n
# 97                                                                                                  Spring tooth harrow \n
# 98                                       Internal combustion motor carburation apparatus and system of control therefor \n
# 99                                                                                             Paper delivery mechanism \n
# 100                                                                                          Transfer material stripper \n

# %%
df_non_inventor = df[(df['is_person_spacy'] == 0)|((df['is_person_spacy'] == 1)&(df['spacy_pos_len'] > 2))]

# %%
len(df) == (len(df_inventor) + len(df_non_inventor))
# Out:
# True

# %%
df_prpn = df_non_inventor[(df_non_inventor['is_prpn_spacy'] == 1) & (df_non_inventor['spacy_pos_len'] <= 2)]

df_non_prpn_1 = df_non_inventor[(df_non_inventor['is_prpn_spacy'] == 1) & (df_non_inventor['spacy_pos_len'] > 2)]
df_non_prpn_2 = df_non_inventor[df_non_inventor['is_prpn_spacy'] == 0]

df_non_prpn = pd.concat([df_non_prpn_1, df_non_prpn_2], ignore_index=True)

# %%
len(df) == (len(df_inventor) + len(df_prpn) + len(df_non_prpn))
# Out:
# True

# %%
len(df)
# Out:
# 99757

# %%
df_non_prpn[['patent_number', 'title', 'spacy_pos']].head(100)
# Out:
#    patent_number  \
# 0           US8A
# 1          US13A
# 2          US24A
# 3          US35A
# 4          US39A
# 5          US46A
# 6          US70A
# 7          US78A
# 8          US87A
# 9          US92A
# 10         US96A
# 11         US98A
# 12        US101A
# 13        US120A
# 14        US127A
# 15        US131A
# 16        US132A
# 17        US136A
# 18        US137A
# 19        US163A
# 20        US165A
# 21        US179A
# 22        US189A
# 23        US198A
# 24        US207A
# 25        US216A
# 26        US217A
# 27        US219A
# 28        US249A
# 29        US258A
# 30        US264A
# 31        US267A
# 32        US277A
# 33        US326A
# 34        US337A
# 35        US339A
# 36        US344A
# 37        US352A
# 38        US358A
# 39        US360A
# 40        US366A
# 41        US378A
# 42        US381A
# 43        US388A
# 44        US389A
# 45        US392A
# 46        US394A
# 47        US400A
# 48        US407A
# 49        US410A
# 50        US420A
# 51        US430A
# 52        US434A
# 53        US435A
# 54        US448A
# 55        US453A
# 56        US454A
# 57        US463A
# 58        US473A
# 59        US488A
# 60        US496A
# 61        US503A
# 62        US506A
# 63        US521A
# 64        US535A
# 65        US545A
# 66        US551A
# 67        US554A
# 68        US559A
# 69        US571A
# 70        US583A
# 71        US585A
# 72        US587A
# 73        US594A
# 74        US595A
# 75        US598A
# 76        US599A
# 77        US605A
# 78        US606A
# 79        US614A
# 80        US617A
# 81        US618A
# 82        US621A
# 83        US636A
# 84        US637A
# 85        US661A
# 86        US663A
# 87        US670A
# 88        US674A
# 89        US700A
# 90        US705A
# 91        US709A
# 92        US733A
# 93        US737A
# 94        US741A
# 95        US744A
# 96        US751A
# 97        US765A
# 98        US770A
# 99        US774A
#
#                                                                                    title  \
# 0           Machine for cutting scores around ships' tackle blocks and dead eyes \n
# 1                                     Mode of laying veneers on ogee and other moldings
# 2                                                                   Mortisistg-maghiite
# 3                                                           Sliding craitk fob sawmills
# 4                                           Purifying- wateil for use in steamt-boilees
# 5                                                  Shuttee-fastejtee poe stoee-wtktdows
# 6                                          Apparatus for preserving and exhibiting maps
# 7                                                       Amasa sizer andx g george sizer
# 8                                                                 X f frictionless pump
# 9                      Machine for nicking or cutting notci-ies in heads of wood-screws
# 10                                                            Temple eor weaving- cloth
# 11                                                                       robinson and f
# 12                                    Method of jcakibtg and furling iw sails fob ships
# 13                                              Mode of constructing steelyard-balances
# 14                                        Mode oe coitstbuctikg bebtch abtd othek vises
# 15                                                   Machine foe cutting eur fedm skins
# 16               Improvement in propelling machinery by magnetism and electro-magnetism
# 17                                                              Mode of molding candles
# 18                                       Register and air-box for grates and fireplaces
# 19                                               Revolving- hand-rake for hay and gbain
# 20                                       Mode of propelling boats ost castals or rivers
# 21     Xg-eoivietrical t trtansxfxerabl-e ivi ivieasurer for iveeasur-ing and draftxing
# 22                                                              Turkabout bob railroads
# 23                                                Mode of constructing boats for canals
# 24                                                    Apparatus used in pointing cannon
# 25                                  Improvement in many-cham b ered-cylin der flre-arms
# 26                                      Apparatus for drawing liquors by compressed air
# 27                                         Mode of dipping or charging locofoco matches
# 28                                                                  Opettf itkeplace ob
# 29                  Improvement in the machine for spreading lime, ashes, marl, plaster
# 30                   Apparatus ob machinery employed in the manufacture of carbonate of
# 31                 Mcode of hanging ob suspending a band-wheel in those hobse-powebs in
# 32                                                                   Levi rice and danl
# 33                                             Mode of constrtjctiire paddle-wheels fob
# 34                                                  Mode of constructing railroad-frogs
# 35               Mode of constructing the wheels of locomotives for asceniding inclined
# 36  Composition of matter to be used as a substitute for gum-senegal in calico-printing
# 37                       Mode of preventing thread from going to waste in machinery for
# 38                                                                  Ximproved m mode of
# 39                                              Mode of cohstkuctiitg paddle-wheels foe
# 40                                                                   Quadrant hinge foe
# 41                                                                    Ho t-aijr strcjve
# 42                                                               Samuel nicolsonj of bo
# 43                                                                   Pantaloon-measurer
# 44                         Mode of supporting the bodies of railroad-cars and carriages
# 45                                                          Mode of making a batting os
# 46                    Mode of regulating the temperature of inkiwg-rollers and ink used
# 47                                         Mode of causing puppet valves to work lights
# 48                                       Mode of supplying air to wood  and coal stoves
# 49                       Method of setting axletrees and in the machinery used therefor
# 50                                       Mode of constructing clamps used by shoemakers
# 51                                                                   Peter henry dreybr
# 52                                 Method of attaching glass kbtobs to metallic sockets
# 53                                                                    Mode of measuring
# 54                                Mode of constructing hubs eor the wheels of carriages
# 55                                       Mode of constructing the gages oe machines eob
# 56                                                       Method obi constructing stoves
# 57                                                   Mode of constructing refrigerators
# 58                                          Mode of constructing double-centered joints
# 59                                              Apparatus fob bobing the hubs of wheels
# 60                                    Mode of com-stbuctiire sawmills fob sawing timber
# 61                       Improvement in the manufacture of india-rubber boots and shoes
# 62                                                                             Doou-sps
# 63                                 Spark-catcher eor arresting awd extinguishing sparks
# 64                                                                  Safety railroad-gar
# 65                                          Method of making fastenings for saddle-bags
# 66                                               Mode of attaching springs to carriages
# 67                                            Mode of constructing and operating churns
# 68                                                        Apparatus for leaching- ashes
# 69                 Method of hanging doors to prevent bain from being forced under them
# 70                                                 Hviprovement in horizontal windmills
# 71                  Apparatus for extinguishing sparks in the chimneys oe steam-boilers
# 72                                                               Machine eor cutting ok
# 73                                            Method of constructing the screw-arms foe
# 74                                                                   X e elijah fairman
# 75                                     Improvement in machines for spreading lime, marl
# 76                                                               Mode of preserving hay
# 77                                                                         Method of mx
# 78                                                        Method of fastening bedsteads
# 79               Discovery in the manufacture of brown paper from a new material called
# 80                                        Mode of operating the treadles in power-looms
# 81                                                Spabk-abeestittg flue fob locomotives
# 82                                             Trap eor catching rats and other animals
# 83                                                               Revolving spring-punch
# 84                                                  Mode of making cast-iron wheels foe
# 85                                                        Mode of making metallic combs
# 86                                  Machine for conveying stkaw prom threshing-machines
# 87               Improved mode of forming raised surfaces for printing on paper, calico
# 88                                                          Draft-box eob steam-engines
# 89                                                                          Photo-litho
# 90                                                            Workingf bellows bt steam
# 91                                                     Gate fob flumes of watekr-wheels
# 92                                                     Machxbte fob hulling clover-seed
# 93                                                Mode of making table knives and forks
# 94                                          Improved process for gilding copper,, brass
# 95                                           Mode of cutting off steam in steam-engines
# 96                                                        Mode of fastening hoe-handles
# 97                               Mode of making and stretching the sacking op bedsteads
# 98               Mode of raising and forcing water by the aid of a triple sliding valve
# 99                      Mode of manufacturing flying shears for the purpose of shearing
#
#                                                                                               spacy_pos
# 0                        [NOUN, ADP, VERB, NOUN, ADP, NOUN, PART, PROPN, NOUN, CCONJ, ADJ, NOUN, SPACE]
# 1                                                 [PROPN, ADP, VERB, NOUN, ADP, NOUN, CCONJ, ADJ, NOUN]
# 2                                                                                  [PROPN, PUNCT, NOUN]
# 3                                                                             [VERB, VERB, PROPN, VERB]
# 4                                                      [PROPN, VERB, ADP, NOUN, ADP, NOUN, PUNCT, NOUN]
# 5                                                          [NOUN, PUNCT, NOUN, PROPN, ADJ, PUNCT, NOUN]
# 6                                                                 [PROPN, ADP, VERB, CCONJ, VERB, NOUN]
# 7                                                             [PROPN, NOUN, PROPN, PROPN, PROPN, PROPN]
# 8                                                                             [PROPN, PROPN, ADJ, NOUN]
# 9                 [NOUN, ADP, VERB, CCONJ, VERB, NOUN, PUNCT, PROPN, ADP, NOUN, ADP, NOUN, PUNCT, NOUN]
# 10                                                                            [PROPN, PROPN, NUM, NOUN]
# 11                                                                                 [PROPN, CCONJ, NOUN]
# 12                                           [PROPN, ADP, NOUN, CCONJ, NOUN, PROPN, PROPN, PROPN, NOUN]
# 13                                                                [PROPN, ADP, VERB, NOUN, PUNCT, NOUN]
# 14                                                      [PROPN, NOUN, PROPN, PROPN, PROPN, PROPN, NOUN]
# 15                                                               [NOUN, NOUN, VERB, PROPN, PROPN, NOUN]
# 16                                        [NOUN, ADP, VERB, NOUN, ADP, NOUN, CCONJ, PROPN, PUNCT, NOUN]
# 17                                                                             [PROPN, ADP, VERB, NOUN]
# 18                                            [PROPN, CCONJ, NOUN, PUNCT, NOUN, ADP, NOUN, CCONJ, NOUN]
# 19                                                   [PROPN, NOUN, PUNCT, NOUN, ADP, NOUN, CCONJ, NOUN]
# 20                                                       [PROPN, ADP, VERB, NOUN, X, NOUN, CCONJ, NOUN]
# 21        [ADJ, PUNCT, ADJ, PROPN, ADJ, PUNCT, NOUN, PROPN, NOUN, ADP, PROPN, PUNCT, NOUN, CCONJ, VERB]
# 22                                                                                  [NOUN, PROPN, NOUN]
# 23                                                                  [PROPN, ADP, VERB, NOUN, ADP, NOUN]
# 24                                                                       [PROPN, VERB, ADP, VERB, NOUN]
# 25                     [NOUN, ADP, ADJ, PUNCT, NOUN, SYM, VERB, PUNCT, NOUN, PROPN, PROPN, PUNCT, NOUN]
# 26                                                            [PROPN, ADP, VERB, NOUN, ADP, VERB, NOUN]
# 27                                                          [PROPN, ADP, VERB, CCONJ, VERB, NOUN, NOUN]
# 28                                                                                   [PROPN, NOUN, ADP]
# 29                      [NOUN, ADP, DET, NOUN, ADP, VERB, NOUN, PUNCT, NOUN, PUNCT, PROPN, PUNCT, NOUN]
# 30                                             [PROPN, ADP, NOUN, VERB, ADP, DET, NOUN, ADP, NOUN, ADP]
# 31              [PROPN, ADP, VERB, ADP, VERB, DET, NOUN, PUNCT, NOUN, ADP, DET, NOUN, PUNCT, NOUN, ADP]
# 32                                                                           [PROPN, NOUN, CCONJ, NOUN]
# 33                                                           [PROPN, ADP, ADJ, NOUN, PUNCT, NOUN, VERB]
# 34                                                                [PROPN, ADP, VERB, NOUN, PUNCT, NOUN]
# 35                                            [PROPN, ADP, VERB, DET, NOUN, ADP, NOUN, ADP, VERB, VERB]
# 36  [NOUN, ADP, NOUN, PART, AUX, VERB, ADP, DET, NOUN, ADP, NOUN, PUNCT, NOUN, ADP, PROPN, PUNCT, VERB]
# 37                                      [PROPN, ADP, VERB, NOUN, ADP, VERB, PART, VERB, ADP, NOUN, ADP]
# 38                                                                            [PROPN, PROPN, NOUN, ADP]
# 39                                                          [PROPN, ADP, NOUN, NOUN, PUNCT, NOUN, VERB]
# 40                                                                                  [PROPN, NOUN, NOUN]
# 41                                                                  [PROPN, PROPN, PUNCT, PROPN, PROPN]
# 42                                                                            [PROPN, NOUN, ADP, PROPN]
# 43                                                                                 [PROPN, PUNCT, NOUN]
# 44                                   [PROPN, ADP, VERB, DET, NOUN, ADP, NOUN, PUNCT, NOUN, CCONJ, NOUN]
# 45                                                                  [PROPN, ADP, VERB, DET, NOUN, NOUN]
# 46                             [PROPN, ADP, VERB, DET, NOUN, ADP, NOUN, PUNCT, NOUN, CCONJ, NOUN, VERB]
# 47                                                     [PROPN, ADP, VERB, NOUN, NOUN, PART, VERB, NOUN]
# 48                                        [PROPN, ADP, VERB, NOUN, ADP, NOUN, SPACE, CCONJ, NOUN, NOUN]
# 49                                           [PROPN, ADP, VERB, NOUN, CCONJ, ADP, DET, NOUN, VERB, ADP]
# 50                                                            [PROPN, ADP, VERB, NOUN, VERB, ADP, NOUN]
# 51                                                                                [PROPN, PROPN, PROPN]
# 52                                                       [PROPN, ADP, VERB, NOUN, NOUN, ADP, ADJ, NOUN]
# 53                                                                                   [PROPN, ADP, VERB]
# 54                                               [PROPN, ADP, VERB, PROPN, PROPN, DET, NOUN, ADP, NOUN]
# 55                                                     [PROPN, ADP, VERB, DET, NOUN, PROPN, NOUN, VERB]
# 56                                                                            [PROPN, NOUN, VERB, NOUN]
# 57                                                                             [PROPN, ADP, VERB, NOUN]
# 58                                                           [PROPN, ADP, VERB, ADJ, PUNCT, VERB, NOUN]
# 59                                                             [PROPN, AUX, VERB, DET, NOUN, ADP, NOUN]
# 60                                              [PROPN, ADP, NOUN, PUNCT, NOUN, NOUN, INTJ, VERB, NOUN]
# 61                                   [NOUN, ADP, DET, NOUN, ADP, PROPN, PUNCT, NOUN, NOUN, CCONJ, NOUN]
# 62                                                                                [PROPN, PUNCT, PROPN]
# 63                                                   [NOUN, PUNCT, NOUN, PROPN, VERB, NOUN, NOUN, NOUN]
# 64                                                                           [NOUN, NOUN, PUNCT, PROPN]
# 65                                                     [PROPN, ADP, VERB, NOUN, ADP, NOUN, PUNCT, NOUN]
# 66                                                                  [PROPN, ADP, VERB, NOUN, ADP, NOUN]
# 67                                                                [PROPN, ADP, VERB, CCONJ, VERB, NOUN]
# 68                                                                              [PROPN, ADP, ADJ, NOUN]
# 69                                [PROPN, ADP, VERB, NOUN, PART, VERB, NOUN, ADP, AUX, VERB, ADP, PRON]
# 70                                                                              [PROPN, ADP, ADJ, NOUN]
# 71                                   [PROPN, ADP, VERB, NOUN, ADP, DET, NOUN, PROPN, NOUN, PUNCT, NOUN]
# 72                                                                             [NOUN, PROPN, VERB, ADP]
# 73                                                     [PROPN, ADP, VERB, DET, NOUN, PUNCT, NOUN, NOUN]
# 74                                                                          [NOUN, PROPN, PROPN, PROPN]
# 75                                                     [NOUN, ADP, NOUN, ADP, VERB, NOUN, PUNCT, PROPN]
# 76                                                                             [PROPN, ADP, VERB, NOUN]
# 77                                                                                  [PROPN, ADP, PROPN]
# 78                                                                             [PROPN, ADP, VERB, NOUN]
# 79                                   [PROPN, ADP, DET, NOUN, ADP, ADJ, NOUN, ADP, DET, ADJ, NOUN, VERB]
# 80                                                [PROPN, ADP, VERB, DET, NOUN, ADP, NOUN, PUNCT, NOUN]
# 81                                                              [PROPN, PUNCT, PROPN, NOUN, NOUN, NOUN]
# 82                                                         [PROPN, PROPN, VERB, NOUN, CCONJ, ADJ, NOUN]
# 83                                                                           [PROPN, NOUN, PUNCT, NOUN]
# 84                                                    [PROPN, ADP, VERB, NOUN, PUNCT, NOUN, NOUN, VERB]
# 85                                                                        [PROPN, ADP, VERB, ADJ, NOUN]
# 86                                                    [NOUN, ADP, VERB, NOUN, NOUN, PROPN, PUNCT, NOUN]
# 87                               [ADJ, NOUN, ADP, VERB, VERB, NOUN, ADP, VERB, ADP, NOUN, PUNCT, PROPN]
# 88                                                       [PROPN, PUNCT, NOUN, PROPN, NOUN, PUNCT, NOUN]
# 89                                                                                 [NOUN, PUNCT, PROPN]
# 90                                                                          [PROPN, VERB, PROPN, PROPN]
# 91                                                         [PROPN, PROPN, NOUN, ADP, NOUN, PUNCT, NOUN]
# 92                                                                [PROPN, ADV, VERB, NOUN, PUNCT, NOUN]
# 93                                                          [PROPN, ADP, VERB, NOUN, NOUN, CCONJ, NOUN]
# 94                                                    [ADJ, NOUN, ADP, PROPN, NOUN, PUNCT, PUNCT, NOUN]
# 95                                                [PROPN, ADP, VERB, ADP, NOUN, ADP, NOUN, PUNCT, NOUN]
# 96                                                                [PROPN, ADP, VERB, NOUN, PUNCT, NOUN]
# 97                                               [PROPN, ADP, VERB, CCONJ, VERB, DET, VERB, NOUN, VERB]
# 98                     [PROPN, ADP, VERB, CCONJ, VERB, NOUN, ADP, DET, NOUN, ADP, DET, ADV, VERB, NOUN]
# 99                                            [PROPN, ADP, VERB, VERB, NOUN, ADP, DET, NOUN, ADP, NOUN]

# %%
len(df)
# Out:
# 99757

# %%
df_dirty = pd.concat([df_inventor, df_prpn], ignore_index=True)
df_dirty
# Out:
#       patent_number                 date               title      spacy_pos  \
# 0              US3A  1836-08-11 00:00:00   Thomas blanchard   [PROPN, NOUN]
# 1              US5A  1836-08-10 00:00:00  Thomas blancharjq   [PROPN, VERB]
# 2              US6A  1836-08-10 00:00:00   Thomas blanghard   [PROPN, NOUN]
# 3              US7A  1836-08-10 00:00:00   Thomas blanchard   [PROPN, NOUN]
# 4              US9A  1836-08-10 00:00:00   Thomas blanchard   [PROPN, NOUN]
# ...             ...                  ...                 ...            ...
# 18323      US99924A           1870-02-15        Orazio lugo   [PROPN, NOUN]
# 18324      US99962A           1870-02-15           George a   [PROPN, PRON]
# 18325      US99969A           1870-02-15       David stuart   [PROPN, VERB]
# 18326      US99990A           1870-02-15    Jerome wheelock   [PROPN, VERB]
# 18327      US99991A           1870-02-15      Silas whitman   [PROPN, VERB]
#
#       spacy_label  is_prpn_spacy  is_person_spacy  spacy_pos_len
# 0        [PERSON]              1                1              2
# 1        [PERSON]              1                1              2
# 2        [PERSON]              1                1              2
# 3        [PERSON]              1                1              2
# 4        [PERSON]              1                1              2
# ...           ...            ...              ...            ...
# 18323          []              1                0              2
# 18324          []              1                0              2
# 18325          []              1                0              2
# 18326          []              1                0              2
# 18327          []              1                0              2
#
# [18328 rows x 8 columns]

# %%
non_terminating_pos = ['ADP', 'CONJ', 'CCONJ', 'DET', 'ADP']

df_non_prpn['bad_endings'] = df['spacy_pos'].apply(lambda x: 1 if x[-1] in non_terminating_pos else 0)

# %%
df_bad_endings = df_non_prpn[df_non_prpn['bad_endings'] == 1]
df_non_bad_endings = df_non_prpn[df_non_prpn['bad_endings'] == 0]

# %%
len(df) == len(df_inventor) + len(df_prpn) + len(df_bad_endings) + len(df_non_bad_endings)
# Out:
# True

# %%
df_non_bad_endings.head()
# Out:
#   patent_number                 date  \
# 0          US8A  1836-08-10 00:00:00
# 1         US13A  1836-08-31 00:00:00
# 2         US24A  1836-09-14 00:00:00
# 3         US35A  1836-09-29 00:00:00
# 4         US39A  1836-10-04 00:00:00
#
#                                                                           title  \
# 0  Machine for cutting scores around ships' tackle blocks and dead eyes \n
# 1                            Mode of laying veneers on ogee and other moldings
# 2                                                          Mortisistg-maghiite
# 3                                                  Sliding craitk fob sawmills
# 4                                  Purifying- wateil for use in steamt-boilees
#
#                                                                         spacy_pos  \
# 0  [NOUN, ADP, VERB, NOUN, ADP, NOUN, PART, PROPN, NOUN, CCONJ, ADJ, NOUN, SPACE]
# 1                           [PROPN, ADP, VERB, NOUN, ADP, NOUN, CCONJ, ADJ, NOUN]
# 2                                                            [PROPN, PUNCT, NOUN]
# 3                                                       [VERB, VERB, PROPN, VERB]
# 4                                [PROPN, VERB, ADP, NOUN, ADP, NOUN, PUNCT, NOUN]
#
#   spacy_label  is_prpn_spacy  is_person_spacy  spacy_pos_len  bad_endings
# 0          []              1                0             13            0
# 1          []              1                0              9            0
# 2      [NORP]              1                0              3            0
# 3          []              1                0              4            0
# 4          []              1                0              8            0

# %%
df_single_pos = df_non_bad_endings[df_non_bad_endings['spacy_pos_len'] == 1]

df_non_single_pos = df_non_bad_endings[df_non_bad_endings['spacy_pos_len'] != 1]

# %%
len(df) == len(df_inventor) + len(df_prpn) + len(df_bad_endings) + len(df_single_pos) + len(df_non_single_pos)
# Out:
# True

# %%
df_non_single_pos['bad_starts'] = df_non_single_pos['spacy_pos'].apply(lambda x: 1 if x[0] in non_terminating_pos else 0)

df_bad_starts = df_non_single_pos[df_non_single_pos['bad_starts'] == 1]
df_non_bad_starts = df_non_single_pos[df_non_single_pos['bad_starts'] == 0]
# Out:
# /var/folders/g2/pczyhkfs3kbcz62x3w_tm8zh0000gn/T/ipykernel_39793/2132829834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_single_pos['bad_starts'] = df_non_single_pos['spacy_pos'].apply(lambda x: 1 if x[0] in non_terminating_pos else 0)

# %%
len(df) == len(df_inventor) + len(df_prpn) + len(df_bad_endings) + len(df_single_pos) + len(df_bad_starts) + len(df_non_bad_starts)
# Out:
# True

# %%
len(df_non_bad_starts)
# Out:
# 74393

# %%
df_non_bad_starts[['title', 'spacy_pos']].head(100)
# Out:
#                                                                                     title  \
# 0            Machine for cutting scores around ships' tackle blocks and dead eyes \n
# 1                                      Mode of laying veneers on ogee and other moldings
# 2                                                                    Mortisistg-maghiite
# 3                                                            Sliding craitk fob sawmills
# 4                                            Purifying- wateil for use in steamt-boilees
# 5                                                   Shuttee-fastejtee poe stoee-wtktdows
# 6                                           Apparatus for preserving and exhibiting maps
# 7                                                        Amasa sizer andx g george sizer
# 8                                                                  X f frictionless pump
# 9                       Machine for nicking or cutting notci-ies in heads of wood-screws
# 10                                                             Temple eor weaving- cloth
# 11                                                                        robinson and f
# 12                                     Method of jcakibtg and furling iw sails fob ships
# 13                                               Mode of constructing steelyard-balances
# 14                                         Mode oe coitstbuctikg bebtch abtd othek vises
# 15                                                    Machine foe cutting eur fedm skins
# 16                Improvement in propelling machinery by magnetism and electro-magnetism
# 17                                                               Mode of molding candles
# 18                                        Register and air-box for grates and fireplaces
# 19                                                Revolving- hand-rake for hay and gbain
# 20                                        Mode of propelling boats ost castals or rivers
# 21      Xg-eoivietrical t trtansxfxerabl-e ivi ivieasurer for iveeasur-ing and draftxing
# 22                                                               Turkabout bob railroads
# 23                                                 Mode of constructing boats for canals
# 24                                                     Apparatus used in pointing cannon
# 25                                   Improvement in many-cham b ered-cylin der flre-arms
# 26                                       Apparatus for drawing liquors by compressed air
# 27                                          Mode of dipping or charging locofoco matches
# 28                                                                   Opettf itkeplace ob
# 29                   Improvement in the machine for spreading lime, ashes, marl, plaster
# 30                    Apparatus ob machinery employed in the manufacture of carbonate of
# 31                  Mcode of hanging ob suspending a band-wheel in those hobse-powebs in
# 32                                                                    Levi rice and danl
# 33                                              Mode of constrtjctiire paddle-wheels fob
# 34                                                   Mode of constructing railroad-frogs
# 35                Mode of constructing the wheels of locomotives for asceniding inclined
# 36   Composition of matter to be used as a substitute for gum-senegal in calico-printing
# 37                        Mode of preventing thread from going to waste in machinery for
# 38                                                                   Ximproved m mode of
# 39                                               Mode of cohstkuctiitg paddle-wheels foe
# 40                                                                    Quadrant hinge foe
# 41                                                                     Ho t-aijr strcjve
# 42                                                                Samuel nicolsonj of bo
# 43                                                                    Pantaloon-measurer
# 44                          Mode of supporting the bodies of railroad-cars and carriages
# 45                                                           Mode of making a batting os
# 46                     Mode of regulating the temperature of inkiwg-rollers and ink used
# 47                                          Mode of causing puppet valves to work lights
# 48                                        Mode of supplying air to wood  and coal stoves
# 49                        Method of setting axletrees and in the machinery used therefor
# 50                                        Mode of constructing clamps used by shoemakers
# 51                                                                    Peter henry dreybr
# 52                                  Method of attaching glass kbtobs to metallic sockets
# 53                                                                     Mode of measuring
# 54                                 Mode of constructing hubs eor the wheels of carriages
# 55                                        Mode of constructing the gages oe machines eob
# 56                                                        Method obi constructing stoves
# 57                                                    Mode of constructing refrigerators
# 58                                           Mode of constructing double-centered joints
# 59                                               Apparatus fob bobing the hubs of wheels
# 60                                     Mode of com-stbuctiire sawmills fob sawing timber
# 61                        Improvement in the manufacture of india-rubber boots and shoes
# 62                                                                              Doou-sps
# 63                                  Spark-catcher eor arresting awd extinguishing sparks
# 64                                                                   Safety railroad-gar
# 65                                           Method of making fastenings for saddle-bags
# 66                                                Mode of attaching springs to carriages
# 67                                             Mode of constructing and operating churns
# 68                                                         Apparatus for leaching- ashes
# 69                  Method of hanging doors to prevent bain from being forced under them
# 70                                                  Hviprovement in horizontal windmills
# 71                   Apparatus for extinguishing sparks in the chimneys oe steam-boilers
# 72                                                                Machine eor cutting ok
# 73                                             Method of constructing the screw-arms foe
# 74                                                                    X e elijah fairman
# 75                                      Improvement in machines for spreading lime, marl
# 76                                                                Mode of preserving hay
# 77                                                                          Method of mx
# 78                                                         Method of fastening bedsteads
# 79                Discovery in the manufacture of brown paper from a new material called
# 80                                         Mode of operating the treadles in power-looms
# 81                                                 Spabk-abeestittg flue fob locomotives
# 82                                              Trap eor catching rats and other animals
# 83                                                                Revolving spring-punch
# 84                                                   Mode of making cast-iron wheels foe
# 85                                                         Mode of making metallic combs
# 86                                   Machine for conveying stkaw prom threshing-machines
# 87                Improved mode of forming raised surfaces for printing on paper, calico
# 88                                                           Draft-box eob steam-engines
# 89                                                                           Photo-litho
# 90                                                             Workingf bellows bt steam
# 91                                                      Gate fob flumes of watekr-wheels
# 92                                                      Machxbte fob hulling clover-seed
# 93                                                 Mode of making table knives and forks
# 95                                            Mode of cutting off steam in steam-engines
# 96                                                         Mode of fastening hoe-handles
# 97                                Mode of making and stretching the sacking op bedsteads
# 98                Mode of raising and forcing water by the aid of a triple sliding valve
# 99                       Mode of manufacturing flying shears for the purpose of shearing
# 100                                                          Mode of fastening bedsteads
#
#                                                                                                spacy_pos
# 0                         [NOUN, ADP, VERB, NOUN, ADP, NOUN, PART, PROPN, NOUN, CCONJ, ADJ, NOUN, SPACE]
# 1                                                  [PROPN, ADP, VERB, NOUN, ADP, NOUN, CCONJ, ADJ, NOUN]
# 2                                                                                   [PROPN, PUNCT, NOUN]
# 3                                                                              [VERB, VERB, PROPN, VERB]
# 4                                                       [PROPN, VERB, ADP, NOUN, ADP, NOUN, PUNCT, NOUN]
# 5                                                           [NOUN, PUNCT, NOUN, PROPN, ADJ, PUNCT, NOUN]
# 6                                                                  [PROPN, ADP, VERB, CCONJ, VERB, NOUN]
# 7                                                              [PROPN, NOUN, PROPN, PROPN, PROPN, PROPN]
# 8                                                                              [PROPN, PROPN, ADJ, NOUN]
# 9                  [NOUN, ADP, VERB, CCONJ, VERB, NOUN, PUNCT, PROPN, ADP, NOUN, ADP, NOUN, PUNCT, NOUN]
# 10                                                                             [PROPN, PROPN, NUM, NOUN]
# 11                                                                                  [PROPN, CCONJ, NOUN]
# 12                                            [PROPN, ADP, NOUN, CCONJ, NOUN, PROPN, PROPN, PROPN, NOUN]
# 13                                                                 [PROPN, ADP, VERB, NOUN, PUNCT, NOUN]
# 14                                                       [PROPN, NOUN, PROPN, PROPN, PROPN, PROPN, NOUN]
# 15                                                                [NOUN, NOUN, VERB, PROPN, PROPN, NOUN]
# 16                                         [NOUN, ADP, VERB, NOUN, ADP, NOUN, CCONJ, PROPN, PUNCT, NOUN]
# 17                                                                              [PROPN, ADP, VERB, NOUN]
# 18                                             [PROPN, CCONJ, NOUN, PUNCT, NOUN, ADP, NOUN, CCONJ, NOUN]
# 19                                                    [PROPN, NOUN, PUNCT, NOUN, ADP, NOUN, CCONJ, NOUN]
# 20                                                        [PROPN, ADP, VERB, NOUN, X, NOUN, CCONJ, NOUN]
# 21         [ADJ, PUNCT, ADJ, PROPN, ADJ, PUNCT, NOUN, PROPN, NOUN, ADP, PROPN, PUNCT, NOUN, CCONJ, VERB]
# 22                                                                                   [NOUN, PROPN, NOUN]
# 23                                                                   [PROPN, ADP, VERB, NOUN, ADP, NOUN]
# 24                                                                        [PROPN, VERB, ADP, VERB, NOUN]
# 25                      [NOUN, ADP, ADJ, PUNCT, NOUN, SYM, VERB, PUNCT, NOUN, PROPN, PROPN, PUNCT, NOUN]
# 26                                                             [PROPN, ADP, VERB, NOUN, ADP, VERB, NOUN]
# 27                                                           [PROPN, ADP, VERB, CCONJ, VERB, NOUN, NOUN]
# 28                                                                                    [PROPN, NOUN, ADP]
# 29                       [NOUN, ADP, DET, NOUN, ADP, VERB, NOUN, PUNCT, NOUN, PUNCT, PROPN, PUNCT, NOUN]
# 30                                              [PROPN, ADP, NOUN, VERB, ADP, DET, NOUN, ADP, NOUN, ADP]
# 31               [PROPN, ADP, VERB, ADP, VERB, DET, NOUN, PUNCT, NOUN, ADP, DET, NOUN, PUNCT, NOUN, ADP]
# 32                                                                            [PROPN, NOUN, CCONJ, NOUN]
# 33                                                            [PROPN, ADP, ADJ, NOUN, PUNCT, NOUN, VERB]
# 34                                                                 [PROPN, ADP, VERB, NOUN, PUNCT, NOUN]
# 35                                             [PROPN, ADP, VERB, DET, NOUN, ADP, NOUN, ADP, VERB, VERB]
# 36   [NOUN, ADP, NOUN, PART, AUX, VERB, ADP, DET, NOUN, ADP, NOUN, PUNCT, NOUN, ADP, PROPN, PUNCT, VERB]
# 37                                       [PROPN, ADP, VERB, NOUN, ADP, VERB, PART, VERB, ADP, NOUN, ADP]
# 38                                                                             [PROPN, PROPN, NOUN, ADP]
# 39                                                           [PROPN, ADP, NOUN, NOUN, PUNCT, NOUN, VERB]
# 40                                                                                   [PROPN, NOUN, NOUN]
# 41                                                                   [PROPN, PROPN, PUNCT, PROPN, PROPN]
# 42                                                                             [PROPN, NOUN, ADP, PROPN]
# 43                                                                                  [PROPN, PUNCT, NOUN]
# 44                                    [PROPN, ADP, VERB, DET, NOUN, ADP, NOUN, PUNCT, NOUN, CCONJ, NOUN]
# 45                                                                   [PROPN, ADP, VERB, DET, NOUN, NOUN]
# 46                              [PROPN, ADP, VERB, DET, NOUN, ADP, NOUN, PUNCT, NOUN, CCONJ, NOUN, VERB]
# 47                                                      [PROPN, ADP, VERB, NOUN, NOUN, PART, VERB, NOUN]
# 48                                         [PROPN, ADP, VERB, NOUN, ADP, NOUN, SPACE, CCONJ, NOUN, NOUN]
# 49                                            [PROPN, ADP, VERB, NOUN, CCONJ, ADP, DET, NOUN, VERB, ADP]
# 50                                                             [PROPN, ADP, VERB, NOUN, VERB, ADP, NOUN]
# 51                                                                                 [PROPN, PROPN, PROPN]
# 52                                                        [PROPN, ADP, VERB, NOUN, NOUN, ADP, ADJ, NOUN]
# 53                                                                                    [PROPN, ADP, VERB]
# 54                                                [PROPN, ADP, VERB, PROPN, PROPN, DET, NOUN, ADP, NOUN]
# 55                                                      [PROPN, ADP, VERB, DET, NOUN, PROPN, NOUN, VERB]
# 56                                                                             [PROPN, NOUN, VERB, NOUN]
# 57                                                                              [PROPN, ADP, VERB, NOUN]
# 58                                                            [PROPN, ADP, VERB, ADJ, PUNCT, VERB, NOUN]
# 59                                                              [PROPN, AUX, VERB, DET, NOUN, ADP, NOUN]
# 60                                               [PROPN, ADP, NOUN, PUNCT, NOUN, NOUN, INTJ, VERB, NOUN]
# 61                                    [NOUN, ADP, DET, NOUN, ADP, PROPN, PUNCT, NOUN, NOUN, CCONJ, NOUN]
# 62                                                                                 [PROPN, PUNCT, PROPN]
# 63                                                    [NOUN, PUNCT, NOUN, PROPN, VERB, NOUN, NOUN, NOUN]
# 64                                                                            [NOUN, NOUN, PUNCT, PROPN]
# 65                                                      [PROPN, ADP, VERB, NOUN, ADP, NOUN, PUNCT, NOUN]
# 66                                                                   [PROPN, ADP, VERB, NOUN, ADP, NOUN]
# 67                                                                 [PROPN, ADP, VERB, CCONJ, VERB, NOUN]
# 68                                                                               [PROPN, ADP, ADJ, NOUN]
# 69                                 [PROPN, ADP, VERB, NOUN, PART, VERB, NOUN, ADP, AUX, VERB, ADP, PRON]
# 70                                                                               [PROPN, ADP, ADJ, NOUN]
# 71                                    [PROPN, ADP, VERB, NOUN, ADP, DET, NOUN, PROPN, NOUN, PUNCT, NOUN]
# 72                                                                              [NOUN, PROPN, VERB, ADP]
# 73                                                      [PROPN, ADP, VERB, DET, NOUN, PUNCT, NOUN, NOUN]
# 74                                                                           [NOUN, PROPN, PROPN, PROPN]
# 75                                                      [NOUN, ADP, NOUN, ADP, VERB, NOUN, PUNCT, PROPN]
# 76                                                                              [PROPN, ADP, VERB, NOUN]
# 77                                                                                   [PROPN, ADP, PROPN]
# 78                                                                              [PROPN, ADP, VERB, NOUN]
# 79                                    [PROPN, ADP, DET, NOUN, ADP, ADJ, NOUN, ADP, DET, ADJ, NOUN, VERB]
# 80                                                 [PROPN, ADP, VERB, DET, NOUN, ADP, NOUN, PUNCT, NOUN]
# 81                                                               [PROPN, PUNCT, PROPN, NOUN, NOUN, NOUN]
# 82                                                          [PROPN, PROPN, VERB, NOUN, CCONJ, ADJ, NOUN]
# 83                                                                            [PROPN, NOUN, PUNCT, NOUN]
# 84                                                     [PROPN, ADP, VERB, NOUN, PUNCT, NOUN, NOUN, VERB]
# 85                                                                         [PROPN, ADP, VERB, ADJ, NOUN]
# 86                                                     [NOUN, ADP, VERB, NOUN, NOUN, PROPN, PUNCT, NOUN]
# 87                                [ADJ, NOUN, ADP, VERB, VERB, NOUN, ADP, VERB, ADP, NOUN, PUNCT, PROPN]
# 88                                                        [PROPN, PUNCT, NOUN, PROPN, NOUN, PUNCT, NOUN]
# 89                                                                                  [NOUN, PUNCT, PROPN]
# 90                                                                           [PROPN, VERB, PROPN, PROPN]
# 91                                                          [PROPN, PROPN, NOUN, ADP, NOUN, PUNCT, NOUN]
# 92                                                                 [PROPN, ADV, VERB, NOUN, PUNCT, NOUN]
# 93                                                           [PROPN, ADP, VERB, NOUN, NOUN, CCONJ, NOUN]
# 95                                                 [PROPN, ADP, VERB, ADP, NOUN, ADP, NOUN, PUNCT, NOUN]
# 96                                                                 [PROPN, ADP, VERB, NOUN, PUNCT, NOUN]
# 97                                                [PROPN, ADP, VERB, CCONJ, VERB, DET, VERB, NOUN, VERB]
# 98                      [PROPN, ADP, VERB, CCONJ, VERB, NOUN, ADP, DET, NOUN, ADP, DET, ADV, VERB, NOUN]
# 99                                             [PROPN, ADP, VERB, VERB, NOUN, ADP, DET, NOUN, ADP, NOUN]
# 100                                                                             [PROPN, ADP, VERB, NOUN]

# %%
df_non_bad_starts['starts_with_improve'] = df_non_bad_starts['title'].apply(lambda x: 1 if x.lower().startswith('improve') else 0)
# Out:
# /var/folders/g2/pczyhkfs3kbcz62x3w_tm8zh0000gn/T/ipykernel_39793/1482897686.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_bad_starts['starts_with_improve'] = df_non_bad_starts['title'].apply(lambda x: 1 if x.lower().startswith('improve') else 0)

# %%
df_non_bad_starts[df_non_bad_starts['starts_with_improve'] == 0][['title', 'spacy_pos']].head(603)
# Out:
#                                                                             title  \
# 0    Machine for cutting scores around ships' tackle blocks and dead eyes \n
# 1                              Mode of laying veneers on ogee and other moldings
# 2                                                            Mortisistg-maghiite
# 3                                                    Sliding craitk fob sawmills
# 4                                    Purifying- wateil for use in steamt-boilees
# ..                                                                            ...
# 665                                                     Comte de fontainemoeeatt
# 666                                                              Tailor s sheaks
# 667                                                                      Ox-yoke
# 668                                           Mode op attaching horses to wagons
# 669                                                  Hviprovement in curing meat
#
#                                                                           spacy_pos
# 0    [NOUN, ADP, VERB, NOUN, ADP, NOUN, PART, PROPN, NOUN, CCONJ, ADJ, NOUN, SPACE]
# 1                             [PROPN, ADP, VERB, NOUN, ADP, NOUN, CCONJ, ADJ, NOUN]
# 2                                                              [PROPN, PUNCT, NOUN]
# 3                                                         [VERB, VERB, PROPN, VERB]
# 4                                  [PROPN, VERB, ADP, NOUN, ADP, NOUN, PUNCT, NOUN]
# ..                                                                              ...
# 665                                                                [PROPN, X, NOUN]
# 666                                                             [PROPN, PART, NOUN]
# 667                                                            [PROPN, PUNCT, NOUN]
# 668                                            [PROPN, NOUN, VERB, NOUN, ADP, NOUN]
# 669                                                        [PROPN, ADP, VERB, NOUN]
#
# [603 rows x 2 columns]

# %% [markdown]
# ### Spell Checker

# %%
from spellchecker import SpellChecker

spell = SpellChecker()
a = 'Imprbvemenf in spring shackle'
a.split()
# Out:
# ['Imprbvemenf', 'in', 'spring', 'shackle']

# %%
# find those words that may be misspelled
misspelled = spell.unknown(a.split())
misspelled
# Out:
# {'imprbvemenf'}

# %%
df_non_bad_starts['title'] = df_non_bad_starts['title'].apply(lambda x: x.replace('-', ' '))
df_non_bad_starts['misspelt_words'] = df_non_bad_starts['title'].apply(lambda x: spell.unknown(x.split()))
df_non_bad_starts['misspelt'] = df_non_bad_starts['misspelt_words'].apply(lambda x: 1 if len(x) > 0 else 0)
# Out:
# /var/folders/g2/pczyhkfs3kbcz62x3w_tm8zh0000gn/T/ipykernel_39793/1874185790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_bad_starts['title'] = df_non_bad_starts['title'].apply(lambda x: x.replace('-', ' '))
# /var/folders/g2/pczyhkfs3kbcz62x3w_tm8zh0000gn/T/ipykernel_39793/1874185790.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_bad_starts['misspelt_words'] = df_non_bad_starts['title'].apply(lambda x: spell.unknown(x.split()))
# /var/folders/g2/pczyhkfs3kbcz62x3w_tm8zh0000gn/T/ipykernel_39793/1874185790.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_bad_starts['misspelt'] = df_non_bad_starts['misspelt_words'].apply(lambda x: 1 if len(x) > 0 else 0)

# %%
df_spelling_errors = df_non_bad_starts[df_non_bad_starts['misspelt'] != 0]
df_non_spelling_errors = df_non_bad_starts[df_non_bad_starts['misspelt'] == 0]

# %%
len(df) == len(df_inventor) + len(df_prpn) + len(df_bad_endings) + len(df_single_pos) + len(df_bad_starts) + len(df_spelling_errors) + len(df_non_spelling_errors)
# Out:
# True

# %%
df_non_spelling_errors[['title', 'misspelt_words']].head(100)
# Out:
#                                                                        title  \
# 6                              Apparatus for preserving and exhibiting maps
# 16   Improvement in propelling machinery by magnetism and electro magnetism
# 17                                                  Mode of molding candles
# 18                           Register and air box for grates and fireplaces
# 23                                    Mode of constructing boats for canals
# 24                                        Apparatus used in pointing cannon
# 26                          Apparatus for drawing liquors by compressed air
# 30       Apparatus ob machinery employed in the manufacture of carbonate of
# 34                                      Mode of constructing railroad frogs
# 37           Mode of preventing thread from going to waste in machinery for
# 40                                                       Quadrant hinge foe
# 44             Mode of supporting the bodies of railroad cars and carriages
# 45                                              Mode of making a batting os
# 47                             Mode of causing puppet valves to work lights
# 48                           Mode of supplying air to wood  and coal stoves
# 50                           Mode of constructing clamps used by shoemakers
# 53                                                        Mode of measuring
# 56                                           Method obi constructing stoves
# 57                                       Mode of constructing refrigerators
# 58                              Mode of constructing double centered joints
# 61           Improvement in the manufacture of india rubber boots and shoes
# 64                                                      Safety railroad gar
# 66                                   Mode of attaching springs to carriages
# 67                                Mode of constructing and operating churns
# 68                                            Apparatus for leaching  ashes
# 69     Method of hanging doors to prevent bain from being forced under them
# 71      Apparatus for extinguishing sparks in the chimneys oe steam boilers
# 73                                Method of constructing the screw arms foe
# 76                                                   Mode of preserving hay
# 79   Discovery in the manufacture of brown paper from a new material called
# 83                                                   Revolving spring punch
# 84                                      Mode of making cast iron wheels foe
# 85                                            Mode of making metallic combs
# 93                                    Mode of making table knives and forks
# 95                               Mode of cutting off steam in steam engines
# 96                                            Mode of fastening hoe handles
# 98   Mode of raising and forcing water by the aid of a triple sliding valve
# 99          Mode of manufacturing flying shears for the purpose of shearing
# 101              Mode of constructing and managing vats fob tanning leather
# 103                                                       Mortise latch fob
# 107                     Apparatus for propelling boats by the action of air
# 109                                                   Mode of raising water
# 110                 Mode of converting a reciprocating into a rotary motion
# 112                                                Mode of generating steam
# 115                                                 Machine for boeing rock
# 117                                   Manner of constructing cooking stoves
# 119   Mode of covering the roofs of buildings with tin plate or other metal
# 121                                              Mode of making metal combs
# 122               Mode of laying off and dressing the runners of millstones
# 133            Apparatus for lifting ships and other vessels from the water
# 134                          Method of punching ob forming the eyes of axes
# 135        Apparatus for extinguishing  sparks and arresting cinders in the
# 138                                                 Mode of constructing ga
# 142                                            Apparatus for handling hides
# 144                                    Apparatus for buying flour and other
# 145   Mode of constructing  the chairs of railroads and attaching the rails
# 149          Mode of preparing the glasses and constructing ti ie frames of
# 152                                      Mode of constructing railroad cars
# 154               Mode of regulating  the jaws of leather crimping machines
# 155                                           Sliding valve fob canal locks
# 157                                            Manufacture of hub bands fob
# 158   Mode of changing  the draft of stoves by means of an elliptical valve
# 159                           Mode of governing and reversing steam engines
# 164                                    Mode of manufacturing cement coffins
# 169                                  Mode of supplying water to locomotives
# 172                                      Mode of obtaining and securing ice
# 174                                                 Padlock and other locks
# 175                       Mode of manufacturing socket hammers and hatchets
# 176      Mode oe supplying steam to promote combustion in furnaces of steam
# 177                                                Mode oe making boxes fob
# 178  Mode of progressing with a pile driving machine by the aid of shifting
# 179                           Mode of finding the area of irregular figures
# 180      Manner of constructing chimney caps for the cure of smoky chimneys
# 184                                              Nathan hunt and caleb hunt
# 186                               Mode of driving machinery by manual power
# 193                          Mode oe preventing explosions in steam boilers
# 195                                                      Revolving hay bake
# 198                       Mode of squaring and finishing the heads of bolts
# 200                             Mode op attaching bodies or boxes to wagons
# 203  Mode of converting  a rotary into a double acting reciprocating motion
# 204                                       Manner of hanging carriage bodies
# 207                                         Mode of hanging carriage bodies
# 209     Mode of constructing the bearings and oil boxes for the journals of
# 213         Mode of constructing  railway bars and manner of fastening same
# 214                                                   Mode of separating ti
# 215                                                  Franklin cooking stove
# 216                                     Apparatus fob the cure of fractures
# 219                      Mode of constructing portable houses for emigrants
# 221                                        Mode of constructing sockets for
# 222      Manner of believing the collars of circular saws from the friction
# 223                                                  Mode oe cutting  seats
# 224                          Mode obi arranging the draft of cooking stoves
# 225               Manner of constructing horse powers for driving machinery
# 228                              Mode oe constructing the draft of chimneys
# 230                                             Mode of dressing millstones
# 231                                              Mode of constructing ships
# 232               Mode of constructing  the elastic spring seats oe saddles
# 234                                         Machine fob  excavating ditches
# 243    Mode of constructing chairs for sustaining and holding the rails for
# 244                            Method op oiling horizontal shafts and axles
#
#     misspelt_words
# 6               {}
# 16              {}
# 17              {}
# 18              {}
# 23              {}
# 24              {}
# 26              {}
# 30              {}
# 34              {}
# 37              {}
# 40              {}
# 44              {}
# 45              {}
# 47              {}
# 48              {}
# 50              {}
# 53              {}
# 56              {}
# 57              {}
# 58              {}
# 61              {}
# 64              {}
# 66              {}
# 67              {}
# 68              {}
# 69              {}
# 71              {}
# 73              {}
# 76              {}
# 79              {}
# 83              {}
# 84              {}
# 85              {}
# 93              {}
# 95              {}
# 96              {}
# 98              {}
# 99              {}
# 101             {}
# 103             {}
# 107             {}
# 109             {}
# 110             {}
# 112             {}
# 115             {}
# 117             {}
# 119             {}
# 121             {}
# 122             {}
# 133             {}
# 134             {}
# 135             {}
# 138             {}
# 142             {}
# 144             {}
# 145             {}
# 149             {}
# 152             {}
# 154             {}
# 155             {}
# 157             {}
# 158             {}
# 159             {}
# 164             {}
# 169             {}
# 172             {}
# 174             {}
# 175             {}
# 176             {}
# 177             {}
# 178             {}
# 179             {}
# 180             {}
# 184             {}
# 186             {}
# 193             {}
# 195             {}
# 198             {}
# 200             {}
# 203             {}
# 204             {}
# 207             {}
# 209             {}
# 213             {}
# 214             {}
# 215             {}
# 216             {}
# 219             {}
# 221             {}
# 222             {}
# 223             {}
# 224             {}
# 225             {}
# 228             {}
# 230             {}
# 231             {}
# 232             {}
# 234             {}
# 243             {}
# 244             {}

# %%
df_inventor.to_csv(f'../data/cleaned/{file}_inventor.csv', index=False)

df_prpn.to_csv(f'../data/cleaned/{file}_proper_nouns.csv', index=False)

df_bad_endings.to_csv(f'../data/cleaned/{file}_incomplete.csv', index=False)

df_single_pos.to_csv(f'../data/cleaned/{file}_single_pos.csv', index=False)

df_bad_starts.to_csv(f'../data/cleaned/{file}_bad_starts.csv', index=False)

df_spelling_errors.to_csv(f'../data/cleaned/{file}_non_bad_starts.csv', index=False)
df_non_spelling_errors.to_csv(f'../data/cleaned/{file}_non_bad_starts.csv', index=False)

# %%
len(df_non_spelling_errors)
# Out:
# 54379

# %%
import glob
path = '../data/preprocessed/'
files = glob.glob(f'{path}*.csv')

# %%
import os
print(os.path.basename(files[0]))
# Out:
# 1600k-1700k.csv

# %%
import glob
path = '../data/cleaned/'
os.listdir(path)
# Out:
# ['1600k-1700k',
#  '3800k-3900k',
#  '700k-800k',
#  '3500k-3600k',
#  '2200k-2300k',
#  '1900k-2000k',
#  '.DS_Store',
#  '.~lock.0-100k.csv#',
#  '1300k-1400k',
#  '3000k-3100k',
#  '500k-600k',
#  '1100k-1200k',
#  '300k-400k',
#  '2800k-2900k',
#  '3200k-3300k',
#  '2500k-2600k',
#  '600k-700k',
#  '1400k-1500k',
#  '1700k-1800k',
#  '2000k-2100k',
#  '800k-900k',
#  '1500k-1600k',
#  '200k-300k',
#  '3900k-4000k',
#  '1800k-1900k',
#  '3600k-3700k',
#  '900k-1000k',
#  '2100k-2200k',
#  '1000k-1100k',
#  '3300k-3400k',
#  '2700k-2800k',
#  '2400k-2500k',
#  '.ipynb_checkpoints',
#  '1200k-1300k',
#  '0-100k',
#  '3100k-3200k',
#  '2600k-2700k',
#  '100k-200k',
#  '2900k-3000k',
#  '400k-500k',
#  '2300k-2400k',
#  '3700k-3800k',
#  '3400k-3500k']

# %%
files.remove('.ipynb_checkpoints')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [162], in <cell line: 1>()
# ----> 1 files.remove('.ipynb_checkpoints')
#
# ValueError: list.remove(x): x not in list

# %%
folders = [
'1600k-1700k',
'3800k-3900k',
'700k-800k',
'3500k-3600k',
'2200k-2300k',
'1900k-2000k',
'1300k-1400k',
 '3000k-3100k',
 '500k-600k',
 '1100k-1200k',
 '300k-400k',
 '2800k-2900k',
 '3200k-3300k',
 '2500k-2600k',
 '600k-700k',
 '1400k-1500k',
 '1700k-1800k',
 '2000k-2100k',
 '800k-900k',
 '1500k-1600k',
 '200k-300k',
 '3900k-4000k',
 '1800k-1900k',
 '3600k-3700k',
 '900k-1000k',
 '2100k-2200k',
 '1000k-1100k',
 '3300k-3400k',
 '2700k-2800k',
 '2400k-2500k',
'1200k-1300k',
 '0-100k',
 '3100k-3200k',
 '2600k-2700k',
 '100k-200k',
 '2900k-3000k',
 '400k-500k',
 '2300k-2400k',
 '3700k-3800k',
 '3400k-3500k'
]

len(folders)
# Out:
# 40

# %%
for folder in folders:
    files = os.listdir(f'{path}{folder}')
    break
# Out:
# ['1600k-1700k_inventor.csv', '1600k-1700k_incomplete.csv', '1600k-1700k_non_spelling_errors.csv', '1600k-1700k_single_pos.csv', '1600k-1700k_proper_nouns.csv', '1600k-1700k_spelling_errors.csv', '1600k-1700k_bad_starts.csv']

# %%
from pathlib import Path
import pandas as pd

# csv_folder = Path('.')  # path to your folder, e.g. to `2022`
# df = pd.concat(pd.read_csv(p) for p in csv_folder.glob('**/*.csv') )

# %%
for p in Path(path).glob('**/*.csv'):
    name = p.name.split('_')[1].split('.')[0]
    if name != 'non_spelling_errors':
        
    break
# Out:
# ../data/cleaned/1600k-1700k/1600k-1700k_inventor.csv
# 1600k-1700k_inventor.csv
# inventor

# %%
dirty_df = pd.concat(pd.read_csv(p) for p in Path(path).glob('**/*.csv') if '_'.join(p.name.split('_')[1:]).split('.')[0] != 'non_spelling_errors')
dirty_df.head()
# Out:
#   patent_number        date                   title  \
# 0    US1600027A  1925-08-28  Climber's belt \n
# 1    US1600128A  1926-01-20            Jack \n
# 2    US1600142A  1924-11-21  Jeweler's tool \n
# 3    US1600178A  1922-08-31           Truss \n
# 4    US1600189A  1926-09-14     Allison reginald m
#
#                          tokens  \
# 0         ["Climber's", 'belt']
# 1                      ['Jack']
# 2         ["Jeweler's", 'tool']
# 3                     ['Truss']
# 4  ['Allison', 'reginald', 'm']
#
#                                                  nltk_pos  \
# 0                  [("Climber's", 'NNP'), ('belt', 'NN')]
# 1                                       [('Jack', 'NNP')]
# 2                  [("Jeweler's", 'NNP'), ('tool', 'NN')]
# 3                                       [('Truss', 'NN')]
# 4  [('Allison', 'NNP'), ('reginald', 'VBZ'), ('m', 'NN')]
#
#                             spacy_pos spacy_label is_prpn_spacy  \
# 0  ['PROPN', 'PART', 'NOUN', 'SPACE']  ['PERSON']             1
# 1                  ['PROPN', 'SPACE']  ['PERSON']             1
# 2  ['PROPN', 'PART', 'NOUN', 'SPACE']  ['PERSON']             1
# 3                  ['PROPN', 'SPACE']  ['PERSON']             1
# 4          ['PROPN', 'PROPN', 'VERB']  ['PERSON']             1
#
#   is_person_spacy  spacy_pos_len  bad_endings  bad_starts misspelt_words  \
# 0               1            4.0          NaN         NaN            NaN
# 1               1            2.0          NaN         NaN            NaN
# 2               1            4.0          NaN         NaN            NaN
# 3               1            2.0          NaN         NaN            NaN
# 4               1            3.0          NaN         NaN            NaN
#
#    misspelt  is_prpn_nltk
# 0       NaN           NaN
# 1       NaN           NaN
# 2       NaN           NaN
# 3       NaN           NaN
# 4       NaN           NaN

# %%
len(dirty_df)
# Out:
# 1968493

# %%
clean_df = pd.concat(pd.read_csv(p) for p in Path(path).glob('**/*.csv') if '_'.join(p.name.split('_')[1:]).split('.')[0] == 'non_spelling_errors')
clean_df.head()
# Out:
#   patent_number        date  \
# 0    US1600004A  1925-05-28
# 1    US1600007A  1923-10-15
# 2    US1600030A  1919-04-10
# 3    US1600034A  1925-03-06
# 4    US1600035A  1925-03-06
#
#                                                                   title  \
# 0                                  Stuffing box for compressors \n
# 1                                  Fuel separator and vaporizer \n
# 2  Process of and apparatus for dehydrating crude petroleum oil \n
# 3                                                   Toggle bolt \n
# 4                                                   Toggle bolt \n
#
#                                                                                      tokens  \
# 0                                                 ['Stuffing', 'box', 'for', 'compressors']
# 1                                                 ['Fuel', 'separator', 'and', 'vaporizer']
# 2  ['Process', 'of', 'and', 'apparatus', 'for', 'dehydrating', 'crude', 'petroleum', 'oil']
# 3                                                                        ['Toggle', 'bolt']
# 4                                                                        ['Toggle', 'bolt']
#
#                                                                                                                                                             nltk_pos  \
# 0                                                                                        [('Stuffing', 'VBG'), ('box', 'NN'), ('for', 'IN'), ('compressors', 'NNS')]
# 1                                                                                         [('Fuel', 'NNP'), ('separator', 'NN'), ('and', 'CC'), ('vaporizer', 'NN')]
# 2  [('Process', 'NN'), ('of', 'IN'), ('and', 'CC'), ('apparatus', 'VB'), ('for', 'IN'), ('dehydrating', 'VBG'), ('crude', 'NN'), ('petroleum', 'NN'), ('oil', 'NN')]
# 3                                                                                                                                [('Toggle', 'NNP'), ('bolt', 'NN')]
# 4                                                                                                                                [('Toggle', 'NNP'), ('bolt', 'NN')]
#
#                                                                           spacy_pos  \
# 0                                        ['PROPN', 'PROPN', 'ADP', 'NOUN', 'SPACE']
# 1                                       ['NOUN', 'NOUN', 'CCONJ', 'PROPN', 'SPACE']
# 2  ['PROPN', 'ADP', 'CCONJ', 'NOUN', 'ADP', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'SPACE']
# 3                                                        ['PROPN', 'NOUN', 'SPACE']
# 4                                                        ['PROPN', 'NOUN', 'SPACE']
#
#   spacy_label  is_prpn_spacy  is_person_spacy  spacy_pos_len  bad_endings  \
# 0          []              1                0              5            0
# 1          []              1                0              5            0
# 2          []              1                0             10            0
# 3     ['ORG']              1                0              3            0
# 4     ['ORG']              1                0              3            0
#
#    bad_starts misspelt_words  misspelt
# 0           0          set()         0
# 1           0          set()         0
# 2           0          set()         0
# 3           0          set()         0
# 4           0          set()         0

# %%
len(clean_df)
# Out:
# 2290186

# %%
dirty_df[['title']].head(100)
# Out:
#                                                               title
# 0                                            Climber's belt \n
# 1                                                      Jack \n
# 2                                            Jeweler's tool \n
# 3                                                     Truss \n
# 4                                               Allison reginald m
# 5                              Cartridge and twister holder \n
# 6              Cartridge containing gas-generating chemical \n
# 7          Liner inserter for teat cups of milking machines \n
# 8                                                    Harrow \n
# 9                                       Bricklayer's hammer \n
# 10                          Antiskid device for automobiles \n
# 11                                         Switch mechanism \n
# 12      Oiler for springs or other devices to be lubricated \n
# 13                                                  Josef haslauer
# 14                 Cleaner for warping machines and beamers \n
# 15                                            Gutter hanger \n
# 16                                                    Chuck \n
# 17                                             Label holder \n
# 18                       Electrolyte for electrolytic cells \n
# 19                                                Hose reel \n
# 20  Thiophenol-sulphonic acid tanning and mordanting agents \n
# 21                                               Jar opener \n
# 22                                              Jack ladder \n
# 23                                                Pump jack \n
# 24                                           Lingerie clasp \n
# 25                      Cap selecting and feeding mechanism \n
# 26                                        Charles ernest griffiths
# 27                                                Meter box \n
# 28                 Azo dyestuffs and process of making same \n
# 29                                            Hose coupling \n
# 30                                Asfllokob to babjkicav kodak ook
# 31                      Cap for bottles or other containers \n
# 32                                              Searchlight \n
# 33                            Jacquard card-cutting machine \n
# 34                                       Dispensing machine \n
# 35                                                   Carton \n
# 36                              Quarry block-sawing machine \n
# 37                                                  Whistle \n
# 38                                            Cigar lighter \n
# 39                                  Traveler's bag and case \n
# 40                                                       William w
# 41                      Multifrequency-current transmission \n
# 42                                          Sinew extractor \n
# 43                     Hose and means of manufacturing same \n
# 44                                                 Silencer \n
# 45                                                 Silencer \n
# 46                               Carpenter's scribing gauge \n
# 47                                            Knob mounting \n
# 48                                             Liner puller \n
# 49                     Cap and ring spinning and like frame \n
# 50                                       James blacklock henderson
# 51                       Prop for motor cycles and the like \n
# 52                                        Albert joseph brownworth
# 53                                                        George h
# 54                                                           Gltje
# 55                                                      Pan \n
# 56     Yarn-carrier-controlling means for knitting machines \n
# 57                                                      wurtenberg
# 58                          Continuous bias-cutting machine \n
# 59                                                   William astle
# 60                                                         Maurice
# 61          Combination test panel and polyphase meter trim \n
# 62                                                      Bin \n
# 63                                           Cotton chopper \n
# 64                                              Fuse holder \n
# 65                                                          Victor
# 66                                               Rod weeder \n
# 67                                               Flow meter \n
# 68                                              Thermometer \n
# 69                                 Silencer for oil burners \n
# 70                                             Bottle crate \n
# 71                                                    Montgomery w
# 72                                               Screw jack \n
# 73                                                      Bat \n
# 74                                              Fuse holder \n
# 75                                                 Scaffold \n
# 76                                            Hose coupling \n
# 77                                        Bowdin controller \n
# 78                                               Glass mold \n
# 79                                          Catcher's glove \n
# 80                                       Cleaner and cutter \n
# 81                                           Cotton chopper \n
# 82                               Collapsible core and chuck \n
# 83                                               Flow meter \n
# 84                                                   Hqwasd parker
# 85                                              Fuse holder \n
# 86                                                Auto jack \n
# 87                                             Vehicle lamp \n
# 88                                              Dispensing machine
# 89                                               Drill head \n
# 90                                             Bottle crate \n
# 91                                            Carboy holder \n
# 92                                            Charles ellis bttbke
# 93                                                Glass jar \n
# 94                                                 Anthony eustace
# 95                                               Bill sheet \n
# 96                                            Gutter hanger \n
# 97                                          Antiskid device \n
# 98                                                     Mill \n
# 99                                                   Shears \n

# %%
import pandas as pd
from tqdm import tqdm
import glob
import os
from spellchecker import SpellChecker
from ast import literal_eval

import warnings
warnings.filterwarnings("ignore")

path = '../data/preprocessed/'
files = glob.glob(f'{path}*.csv')
spell = SpellChecker()

def bad_ending_patents(pos):
    if len(pos) > 0:
        if pos[-1] in non_terminating_pos:
            return 1
        return 0
    else:
        return 0

def bad_starting_patents(pos):
    if len(pos) > 0:
        if pos[0] in non_starting_pos:
            return 1
        return 0
    else:
        return 0
    
def remove_spacy_pos_space(pos):
    if pos[-1] == 'SPACE':
        return pos[:-1]
    return pos[:]

for file in tqdm(files):
    name = file.split('/')[-1]
    df = pd.read_csv(f'{path}{name}', converters={'tokens': literal_eval, 'nltk_pos': literal_eval, 'spacy_pos': literal_eval,'spacy_label': literal_eval,})
    df['is_person_spacy'] = df['spacy_label'].apply(lambda x: 1 if 'PERSON' in x else 0)
    df['spacy_pos_len'] = df['spacy_pos'].apply(len)
    df['title'] = df['title'].astype(str)
    df['title'] = df['title'].apply(lambda x: x.strip()) # stripping next line spacy in title endings
    df['spacy_pos'] = df['spacy_pos'].apply(lambda x: x[:-1] if x[-1] == 'SPACE' else x)
    df_inventor = df[df['is_person_spacy'] == 1]
    df_non_inventor = df[df['is_person_spacy'] == 0]
    df_prpn = df_non_inventor[(df_non_inventor['is_prpn_spacy'] == 1) & (df_non_inventor['spacy_pos_len'] <= 2)]
    df_non_prpn_1 = df_non_inventor[(df_non_inventor['is_prpn_spacy'] == 1) & (df_non_inventor['spacy_pos_len'] > 2)]
    df_non_prpn_2 = df_non_inventor[df_non_inventor['is_prpn_spacy'] == 0]
    df_non_prpn = pd.concat([df_non_prpn_1, df_non_prpn_2], ignore_index=True)
    print(len(df) == (len(df_inventor) + len(df_prpn) + len(df_non_prpn)))
    
#     non_terminating_pos = ['ADP', 'CONJ', 'CCONJ', 'DET', 'ADP']
#     non_starting_pos = ['ADP', 'CONJ', 'CCONJ','ADP']
    
#     df_non_prpn['bad_endings'] = df['spacy_pos'].apply(bad_ending_patents)
#     df_bad_endings = df_non_prpn[df_non_prpn['bad_endings'] == 1]
#     df_non_bad_endings = df_non_prpn[df_non_prpn['bad_endings'] == 0]
#     print(len(df) == (len(df_inventor) + len(df_prpn) + len(df_bad_endings)+ len(df_non_bad_endings)))

#     df_single_pos = df_non_bad_endings[df_non_bad_endings['spacy_pos_len'] == 1]
#     df_non_single_pos = df_non_bad_endings[df_non_bad_endings['spacy_pos_len'] != 1]
#     print(len(df) == (len(df_inventor) + len(df_prpn) + len(df_bad_endings)+ len(df_single_pos) + len(df_non_single_pos)))

#     df_non_single_pos['bad_starts'] = df_non_single_pos['spacy_pos'].apply(bad_starting_patents)
#     df_bad_starts = df_non_single_pos[df_non_single_pos['bad_starts'] == 1]
#     df_non_bad_starts = df_non_single_pos[df_non_single_pos['bad_starts'] == 0]
#     print(len(df) == (len(df_inventor) + len(df_prpn) + len(df_bad_endings)+ len(df_single_pos) + len(df_bad_starts) + len(df_non_bad_starts)))

#     df_non_bad_starts['title'] = df_non_bad_starts['title'].apply(lambda x: x.replace('-', ' '))
#     df_non_bad_starts['misspelt_words'] = df_non_bad_starts['title'].apply(lambda x: spell.unknown(x.split()))
#     df_non_bad_starts['misspelt'] = df_non_bad_starts['misspelt_words'].apply(lambda x: 1 if len(x) > 0 else 0)
#     df_spelling_errors = df_non_bad_starts[df_non_bad_starts['misspelt'] != 0]
#     df_non_spelling_errors = df_non_bad_starts[df_non_bad_starts['misspelt'] == 0]
#     print(len(df) == (len(df_inventor) + len(df_prpn) + len(df_bad_endings)+ len(df_single_pos) + len(df_bad_starts) + len(df_spelling_errors) + len(df_non_spelling_errors)))

#     if len(df) == (len(df_inventor) + len(df_prpn) + len(df_bad_endings) + len(df_single_pos) + len(df_bad_starts) + len(df_spelling_errors) + len(df_non_spelling_errors)):
#         name = os.path.basename(name).split('.')[0]
#         save_path = '../data/cleaned/'
#         os.mkdir(f"{save_path}{name}")

#         df_inventor.to_csv(f'../data/cleaned/{name}/{name}_inventor.csv', index=False)
#         df_prpn.to_csv(f'../data/cleaned/{name}/{name}_proper_nouns.csv', index=False)
#         df_bad_endings.to_csv(f'../data/cleaned/{name}/{name}_incomplete.csv', index=False)
#         df_single_pos.to_csv(f'../data/cleaned/{name}/{name}_single_pos.csv', index=False)
#         df_bad_starts.to_csv(f'../data/cleaned/{name}/{name}_bad_starts.csv', index=False)
#         df_spelling_errors.to_csv(f'../data/cleaned/{name}/{name}_spelling_errors.csv', index=False)
#         df_non_spelling_errors.to_csv(f'../data/cleaned/{name}/{name}_non_spelling_errors.csv', index=False)
    break
# Out:
#   0%|                                                                                                                                  | 0/40 [00:03<?, ?it/s]
# True

# %%
df_non_prpn.head()
# Out:
#   patent_number        date  \
# 0    US1600004A  1925-05-28
# 1    US1600007A  1923-10-15
# 2    US1600030A  1919-04-10
# 3    US1600031A  1925-06-20
# 4    US1600034A  1925-03-06
#
#                                                                    title  \
# 0                                           Stuffing box for compressors
# 1                                           Fuel separator and vaporizer
# 2           Process of and apparatus for dehydrating crude petroleum oil
# 3  Teapot, coffeepot, and other pouring vessels provided with loose lids
# 4                                                            Toggle bolt
#
#                                                                              tokens  \
# 0                                                 [Stuffing, box, for, compressors]
# 1                                                 [Fuel, separator, and, vaporizer]
# 2            [Process, of, and, apparatus, for, dehydrating, crude, petroleum, oil]
# 3  [Teapot,, coffeepot,, and, other, pouring, vessels, provided, with, loose, lids]
# 4                                                                    [Toggle, bolt]
#
#                                                                                                                                            nltk_pos  \
# 0                                                                                       [(Stuffing, VBG), (box, NN), (for, IN), (compressors, NNS)]
# 1                                                                                        [(Fuel, NNP), (separator, NN), (and, CC), (vaporizer, NN)]
# 2                     [(Process, NN), (of, IN), (and, CC), (apparatus, VB), (for, IN), (dehydrating, VBG), (crude, NN), (petroleum, NN), (oil, NN)]
# 3  [(Teapot,, NNP), (coffeepot,, NN), (and, CC), (other, JJ), (pouring, NN), (vessels, NNS), (provided, VBN), (with, IN), (loose, JJ), (lids, NNS)]
# 4                                                                                                                       [(Toggle, NNP), (bolt, NN)]
#
#                                                                    spacy_pos  \
# 0                                                  [PROPN, PROPN, ADP, NOUN]
# 1                                                 [NOUN, NOUN, CCONJ, PROPN]
# 2                      [PROPN, ADP, CCONJ, NOUN, ADP, VERB, ADJ, NOUN, NOUN]
# 3  [PROPN, PUNCT, NOUN, PUNCT, CCONJ, ADJ, NOUN, NOUN, VERB, ADP, ADJ, NOUN]
# 4                                                              [PROPN, NOUN]
#
#   spacy_label  is_prpn_spacy  is_person_spacy  spacy_pos_len
# 0          []              1                0              5
# 1          []              1                0              5
# 2          []              1                0             10
# 3          []              1                0             13
# 4       [ORG]              1                0              3

# %%
if df_non_prpn.iloc[0]['spacy_pos'][-1] == 'SPACE':
    print(df_non_prpn.iloc[0]['spacy_pos'][:-1])
# Out:
# ['PROPN', 'PROPN', 'ADP', 'NOUN']
